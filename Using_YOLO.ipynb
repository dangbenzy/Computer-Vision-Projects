# %% [markdown]
# <a href="https://colab.research.google.com/github/dangbenzy/Projects/blob/main/Using_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q ultralytics

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os

# %%
def prediction(model_type, img_path, display_result = False, task : str = None):

    model = YOLO(model_type)
    result = model(img_path, save = True, conf=0.5)

    for r in result:
        pred_img_path = f"{r.save_dir}/{os.path.basename(img_path)}"
        pred = cv2.cvtColor(cv2.imread(pred_img_path), cv2.COLOR_BGR2RGB)
        plt.imshow(pred)
        plt.axis('off')
        plt.title(f"YOLO11 - {task}")
    plt.show()

    if display_result:
       print(result)

# %% [markdown]
# Object Detection with YOLO

# %%
img_path = '/content/drive/MyDrive/data/Images/5.jpg'
model_type = "yolo11l.pt"

prediction(model_type, img_path, task = "Object Detection")
# Out:
# image 1/1 /content/drive/MyDrive/data/Images/5.jpg: 640x512 5 persons, 2095.0ms
# Speed: 4.8ms preprocess, 2095.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /content/runs/detect/predict10

# %%
img_path = '/content/drive/MyDrive/data/Images/6.jpg'
model_type = "yolo11l.pt"

prediction(model_type, img_path, task = "Object Detection")
# Out:
# image 1/1 /content/drive/MyDrive/data/Images/6.jpg: 384x640 2 persons, 1 airplane, 943.7ms
# Speed: 2.6ms preprocess, 943.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict11

# %% [markdown]
# Pose Estimation

# %%
model_type = "yolo11l-pose.pt"
img_path = "/content/drive/MyDrive/data/Images/4.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Pose Estimation")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11l-pose.pt to 'yolo11l-pose.pt': 100% ━━━━━━━━━━━━ 50.7MB 81.5MB/s 0.6s
#
# image 1/1 /content/drive/MyDrive/data/Images/4.jpg: 448x640 4 persons, 1363.8ms
# Speed: 3.2ms preprocess, 1363.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/pose/predict

# %% [markdown]
# Instance Segmentation

# %%
model_type = "yolo11l-seg.pt"
img_path = "/content/drive/MyDrive/data/Images/4.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Instance Segmentation", display_result = False)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11l-seg.pt to 'yolo11l-seg.pt': 100% ━━━━━━━━━━━━ 53.5MB 166.8MB/s 0.3s
#
# image 1/1 /content/drive/MyDrive/data/Images/4.jpg: 448x640 5 persons, 1 umbrella, 2 ties, 1586.6ms
# Speed: 3.2ms preprocess, 1586.6ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/segment/predict

# %% [markdown]
# Image Classification

# %%
model_type = "yolo11l-cls.pt"
img_path = "/content/drive/MyDrive/data/Images/6.jpg"

# Predict with the model
prediction(model_type, img_path, task = "Classification")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11l-cls.pt to 'yolo11l-cls.pt': 100% ━━━━━━━━━━━━ 27.2MB 153.1MB/s 0.2s
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.1MB/s 0.0s
# image 1/1 /content/drive/MyDrive/data/Images/6.jpg: 224x224 warplane 0.76, projectile 0.11, airliner 0.05, torch 0.02, missile 0.01, 141.0ms
# Speed: 35.0ms preprocess, 141.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
